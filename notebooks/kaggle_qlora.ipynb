# %% [markdown]
# # QLoRA fine-tuning / distillation on Kaggle (30h/week) — fine-tune-lab
#
# Phase 0 stub. Thin driver over `src/fine_tune_lab/train/` and `src/fine_tune_lab/distill/`.
# Use **QLoRA (4-bit, bitsandbytes)** to fit a larger base in Kaggle's free GPU VRAM.
#
# See `docs/modules/train.md`, `docs/modules/distill.md`, `docs/adr/0001-stack-and-scope.md`.
# **Never use real patient data — synthetic only.**

# %% [markdown]
# ## Steps
# 1. **Settings → Accelerator → GPU.** Mind the 30h/week quota.
# 2. Install the package: `pip install -e .`
# 3. Pull the dataset (with teacher `rationale` / `teacher_logprobs` for distillation).
# 4. **QLoRA track:** `TrainConfig(use_4bit=True, ...)` then `train_lora(config)`.
# 5. **Distill track:** `DistillConfig(...)` then `distill(config)` (soft + hard targets).
# 6. Save the artifact; run `eval/metrics.py` to add its row to the before/after table.
#
# Watch: teacher-bias propagation, soft-target availability, diminishing returns vs plain LoRA.

# %%
# Phase 0 stub — wiring lands in Phase 1.
# !pip install -e .
#
# from fine_tune_lab.train.config import TrainConfig
# from fine_tune_lab.train.lora import train_lora
# train_lora(TrainConfig(use_4bit=True))
#
# from fine_tune_lab.distill.config import DistillConfig
# from fine_tune_lab.distill.distill import distill
# distill(DistillConfig())
